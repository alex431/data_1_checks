# %%
import requests
import pandas as pd

# %%
r = requests.get("https://api.artic.edu/api/v1/artworks")
print(type(r.json()))
print(r.json().keys())
# Out:
# <class 'dict'>
# dict_keys(['pagination', 'data', 'info', 'config'])

# %%
r.json()['data']
# Out:
# [{'id': 130620,
#   'api_model': 'artworks',
#   'api_link': 'https://api.artic.edu/api/v1/artworks/130620',
#   'is_boosted': False,
#   'title': 'God Brahma',
#   'alt_titles': None,
#   'thumbnail': {'lqip': '...',
#    'width': 1590,
#    'height': 2250,
#    'alt_text': 'A work made of basalt.'},
#   'main_reference_number': '2019.725',
#   'has_not_been_viewed_much': True,
#   'boost_rank': None,
#   'date_start': 800,
#   'date_end': 900,
#   'date_display': 'Pala Period, c. 9th century',
#   'date_qualifier_title': '',
#   'date_qualifier_id': None,
#   'artist_display': 'India\nBihar',
#   'place_of_origin': 'Bihar',
#   'dimensions': '57.8 × 32.4 × 15.4 cm (22 3/4 × 12 3/4 × 6 1/16 in.)',
#   'medium_display': 'Basalt',
#   'inscriptions': None,
#   'credit_line': 'Gift of Marilynn B. Alsdorf',
#   'catalogue_display': None,
#   'publication_history': None,
#   'exhibition_history': None,
#   'provenance_text': None,
#   'publishing_verification_level': 'Web Basic',
#   'internal_department_id': 8,
#   'fiscal_year': 2019,
#   'fiscal_year_deaccession': None,
#   'is_public_domain': True,
#   'is_zoomable': True,
#   'max_zoom_window_size': -1,
#   'copyright_notice': None,
#   'has_multimedia_resources': False,
#   'has_educational_resources': False,
#   'has_advanced_imaging': False,
#   'colorfulness': 15.6395,
#   'color': {'h': 214,
#    'l': 51,
#    's': 14,
#    'percentage': 0.03569656527450062,
#    'population': 359},
#   'latitude': None,
#   'longitude': None,
#   'latlon': None,
#   'is_on_view': False,
#   'on_loan_display': None,
#   'gallery_title': None,
#   'gallery_id': None,
#   'artwork_type_title': 'Sculpture',
#   'artwork_type_id': 3,
#   'department_title': 'Arts of Asia',
#   'department_id': 'PC-7',
#   'artist_id': None,
#   'artist_title': None,
#   'alt_artist_ids': [],
#   'artist_ids': [],
#   'artist_titles': [],
#   'category_ids': ['PC-7', 'PC-104', 'PC-103'],
#   'category_titles': ['Arts of Asia', 'South Asian', 'Japanese'],
#   'term_titles': ['basalt (basic igneous rock)',
#    'stone',
#    'South Asian',
#    'sculpture',
#    'asian art'],
#   'style_id': 'TM-5344',
#   'style_title': 'South Asian',
#   'alt_style_ids': [],
#   'style_ids': ['TM-5344'],
#   'style_titles': ['South Asian'],
#   'classification_id': 'TM-96',
#   'classification_title': 'stone',
#   'alt_classification_ids': ['TM-13', 'TM-26'],
#   'classification_ids': ['TM-96', 'TM-13', 'TM-26'],
#   'classification_titles': ['stone', 'sculpture', 'asian art'],
#   'subject_id': None,
#   'alt_subject_ids': [],
#   'subject_ids': [],
#   'subject_titles': [],
#   'material_id': 'TM-2445',
#   'alt_material_ids': [],
#   'material_ids': ['TM-2445'],
#   'material_titles': ['basalt (basic igneous rock)'],
#   'technique_id': None,
#   'alt_technique_ids': [],
#   'technique_ids': [],
#   'technique_titles': [],
#   'theme_titles': [],
#   'image_id': '75bd335b-c060-2be1-3ca6-f85a096b4309',
#   'alt_image_ids': [],
#   'document_ids': [],
#   'sound_ids': [],
#   'video_ids': [],
#   'text_ids': [],
#   'section_ids': [],
#   'section_titles': [],
#   'site_ids': [],
#   'suggest_autocomplete_all': [{'input': ['2019.725'],
#     'contexts': {'groupings': ['accession']}},
#    {'input': ['God Brahma'],
#     'weight': 1,
#     'contexts': {'groupings': ['title']}}],
#   'source_updated_at': '2023-02-09T15:12:21-06:00',
#   'updated_at': '2023-02-09T15:17:14-06:00',
#   'timestamp': '2023-02-09T15:24:09-06:00'},
#  {'id': 243588,
#   'api_model': 'artworks',
#   'api_link': 'https://api.artic.edu/api/v1/artworks/243588',
#   'is_boosted': False,
#   'title': 'Jannat',
#   'alt_titles': None,
#   'thumbnail': {'lqip': '...',
#    'width': 5216,
#    'height': 7763,
#    'alt_text': 'A work made of inkjet print.'},
#   'main_reference_number': '2018.158d',
#   'has_not_been_viewed_much': True,
#   'boost_rank': None,
#   'date_start': 1999,
#   'date_end': 2007,
#   'date_display': '1999–2007',
#   'date_qualifier_title': 'Made',
#   'date_qualifier_id': 4,
#   'artist_display': 'Gauri Gill\nIndian, born 1970',
#   'place_of_origin': 'India',
#   'dimensions': 'Image, approx: 33.8 × 21 cm (13 5/16 × 8 5/16 in.); Paper, sight: 35 × 22.3 cm (13 13/16 × 8 13/16 in.); Frame: 37 × 24.3 × 2 cm (14 5/8 × 9 5/8 × 13/16 in.)',
#   'medium_display': 'Inkjet print',
#   'inscriptions': None,
#   'credit_line': 'Gift of Meredith and Akhil Sharma',
#   'catalogue_display': None,
#   'publication_history': None,
#   'exhibition_history': None,
#   'provenance_text': None,
#   'publishing_verification_level': 'Web Basic',
#   'internal_department_id': 20,
#   'fiscal_year': 2018,
#   'fiscal_year_deaccession': None,
#   'is_public_domain': False,
#   'is_zoomable': False,
#   'max_zoom_window_size': 843,
#   'copyright_notice': None,
#   'has_multimedia_resources': False,
#   'has_educational_resources': False,
#   'has_advanced_imaging': False,
#   'colorfulness': 8.34,
#   'color': {'h': 40,
#    'l': 50,
#    's': 7,
#    'percentage': 0.02232476478589983,
#    'population': 236},
#   'latitude': None,
#   'longitude': None,
#   'latlon': None,
#   'is_on_view': False,
#   'on_loan_display': None,
#   'gallery_title': None,
#   'gallery_id': None,
#   'artwork_type_title': 'Photograph',
#   'artwork_type_id': 2,
#   'department_title': 'Photography and Media',
#   'department_id': 'PC-12',
#   'artist_id': 116076,
#   'artist_title': 'Gauri Gill',
#   'alt_artist_ids': [],
#   'artist_ids': [116076],
#   'artist_titles': ['Gauri Gill'],
#   'category_ids': ['PC-825', 'PC-12'],
#   'category_titles': ['Women artists', 'Photography and Media'],
#   'term_titles': ['gelatin silver print',
#    'India',
#    'contemporary',
#    'photograph',
#    'photography',
#    'portrait',
#    'portrait',
#    'black-and-white photography',
#    'photography',
#    '20th Century',
#    'portraits: Indian subject',
#    'documentary',
#    '21st Century'],
#   'style_id': 'TM-12062',
#   'style_title': 'contemporary',
#   'alt_style_ids': ['TM-13130', 'TM-12913'],
#   'style_ids': ['TM-12062', 'TM-13130', 'TM-12913'],
#   'style_titles': ['contemporary', '20th Century', '21st Century'],
#   'classification_id': 'TM-966',
#   'classification_title': 'gelatin silver print',
#   'alt_classification_ids': ['TM-240', 'TM-67', 'TM-12855', 'TM-12924'],
#   'classification_ids': ['TM-966', 'TM-240', 'TM-67', 'TM-12855', 'TM-12924'],
#   'classification_titles': ['gelatin silver print',
#    'photograph',
#    'photography',
#    'portrait',
#    'portrait'],
#   'subject_id': 'TM-13263',
#   'alt_subject_ids': ['TM-8596', 'TM-13647'],
#   'subject_ids': ['TM-13263', 'TM-8596', 'TM-13647'],
#   'subject_titles': ['India', 'portraits: Indian subject', 'documentary'],
#   'material_id': None,
#   'alt_material_ids': [],
#   'material_ids': [],
#   'material_titles': [],
#   'technique_id': None,
#   'alt_technique_ids': ['TM-12089', 'TM-3978'],
#   'technique_ids': ['TM-12089', 'TM-3978'],
#   'technique_titles': ['black-and-white photography', 'photography'],
#   'theme_titles': ['Women artists'],
#   'image_id': '820d2b69-577d-8c7f-d026-13318acb8683',
#   'alt_image_ids': [],
#   'document_ids': [],
#   'sound_ids': [],
#   'video_ids': [],
#   'text_ids': [],
#   'section_ids': [],
#   'section_titles': [],
#   'site_ids': [],
#   'suggest_autocomplete_all': [{'input': ['2018.158d'],
#     'contexts': {'groupings': ['accession']}},
#    {'input': ['Jannat'], 'weight': 1, 'contexts': {'groupings': ['title']}}],
#   'source_updated_at': '2023-02-09T15:12:22-06:00',
#   'updated_at': '2023-02-09T15:17:13-06:00',
#   'timestamp': '2023-02-09T15:24:09-06:00'},
#  {'id': 69725,
#   'api_model': 'artworks',
#   'api_link': 'https://api.artic.edu/api/v1/artworks/69725',
#   'is_boosted': False,
#   'title': 'Ewer with Incised Floral Decoration',
#   'alt_titles': None,
#   'thumbnail': {'lqip': '...',
#    'width': 1831,
#    'height': 2250,
#    'alt_text': 'A work made of gombroon ware; fritware with incised decoration under transparent glaze.'},
#   'main_reference_number': '1914.31',
#   'has_not_been_viewed_much': True,
#   'boost_rank': None,
#   'date_start': 1650,
#   'date_end': 1750,
#   'date_display': 'Safavid dynasty, late 17th/early 18th century',
#   'date_qualifier_title': '',
#   'date_qualifier_id': None,
#   'artist_display': 'Iran\nGombroon (now Bandar Abbas)',
#   'place_of_origin': 'Iran',
#   'dimensions': '23.7 × 17.7 × 13.9 cm (9 5/16 × 7 × 5 1/2 in.)',
#   'medium_display': 'Gombroon ware; fritware with incised decoration under transparent glaze',
#   'inscriptions': None,
#   'credit_line': 'Mary Jane Gunsaulus Collection',
#   'catalogue_display': None,
#   'publication_history': None,
#   'exhibition_history': None,
#   'provenance_text': None,
#   'publishing_verification_level': 'Web Basic',
#   'internal_department_id': 8,
#   'fiscal_year': None,
#   'fiscal_year_deaccession': None,
#   'is_public_domain': True,
#   'is_zoomable': True,
#   'max_zoom_window_size': -1,
#   'copyright_notice': None,
#   'has_multimedia_resources': False,
#   'has_educational_resources': False,
#   'has_advanced_imaging': False,
#   'colorfulness': 6.4038,
#   'color': {'h': 233,
#    'l': 67,
#    's': 4,
#    'percentage': 0.8041468005880817,
#    'population': 7023},
#   'latitude': None,
#   'longitude': None,
#   'latlon': None,
#   'is_on_view': True,
#   'on_loan_display': None,
#   'gallery_title': 'Gallery 143',
#   'gallery_id': 26131,
#   'artwork_type_title': 'Ceramics',
#   'artwork_type_id': 36,
#   'department_title': 'Arts of Asia',
#   'department_id': 'PC-7',
#   'artist_id': 29882,
#   'artist_title': 'Islamic',
#   'alt_artist_ids': [],
#   'artist_ids': [29882],
#   'artist_titles': ['Islamic'],
#   'category_ids': ['PC-7'],
#   'category_titles': ['Arts of Asia'],
#   'term_titles': ['ewer (vessel)',
#    'fritware',
#    'vessel',
#    'porcelain',
#    'ceramic',
#    'asian art',
#    'ceramics',
#    'Islamic (culture or style)'],
#   'style_id': None,
#   'style_title': None,
#   'alt_style_ids': ['TM-13482'],
#   'style_ids': ['TM-13482'],
#   'style_titles': ['Islamic (culture or style)'],
#   'classification_id': 'TM-11952',
#   'classification_title': 'ewer (vessel)',
#   'alt_classification_ids': ['TM-27', 'TM-38', 'TM-26', 'TM-46'],
#   'classification_ids': ['TM-11952', 'TM-27', 'TM-38', 'TM-26', 'TM-46'],
#   'classification_titles': ['ewer (vessel)',
#    'vessel',
#    'porcelain',
#    'asian art',
#    'ceramics'],
#   'subject_id': None,
#   'alt_subject_ids': [],
#   'subject_ids': [],
#   'subject_titles': [],
#   'material_id': 'TM-11966',
#   'alt_material_ids': ['TM-2432'],
#   'material_ids': ['TM-11966', 'TM-2432'],
#   'material_titles': ['fritware', 'ceramic'],
#   'technique_id': None,
#   'alt_technique_ids': [],
#   'technique_ids': [],
#   'technique_titles': [],
#   'theme_titles': [],
#   'image_id': '46a69542-79bf-618f-b675-c65fe799a3df',
#   'alt_image_ids': [],
#   'document_ids': [],
#   'sound_ids': [],
#   'video_ids': [],
#   'text_ids': [],
#   'section_ids': [],
#   'section_titles': [],
#   'site_ids': [],
#   'suggest_autocomplete_all': [{'input': ['1914.31'],
#     'contexts': {'groupings': ['accession']}},
#    {'input': ['Ewer with Incised Floral Decoration'],
#     'weight': 122,
#     'contexts': {'groupings': ['title']}}],
#   'source_updated_at': '2023-02-09T15:15:53-06:00',
#   'updated_at': '2023-02-09T15:17:13-06:00',
#   'timestamp': '2023-02-09T15:24:09-06:00'},
#  {'id': 266236,
#   'api_model': 'artworks',
#   'api_link': 'https://api.artic.edu/api/v1/artworks/266236',
#   'is_boosted': False,
#   'title': 'Teeth Cases, Mexico',
#   'alt_titles': None,
#   'thumbnail': None,
#   'main_reference_number': '2022.1722',
#   'has_not_been_viewed_much': True,
#   'boost_rank': None,
#   'date_start': 1975,
#   'date_end': 1975,
#   'date_display': '1975',
#   'date_qualifier_title': 'Made',
#   'date_qualifier_id': 4,
#   'artist_display': 'Eve Sonneman\nAmerican, born 1950',
#   'place_of_origin': 'United States',
#   'dimensions': 'Image: 10.9 × 33.5 cm (4 5/16 × 13 1/4 in.); paper: 12.3 × 34.2 cm (4 7/8 × 13 1/2 in.); mount: 28 × 45.8 cm (11 1/16 × 18 1/16 in.)',
#   'medium_display': 'Gelatin silver print',
#   'inscriptions': None,
#   'credit_line': 'Gift of the Daniel Weinberg Family',
#   'catalogue_display': None,
#   'publication_history': None,
#   'exhibition_history': None,
#   'provenance_text': None,
#   'publishing_verification_level': 'Web Basic',
#   'internal_department_id': 20,
#   'fiscal_year': 2023,
#   'fiscal_year_deaccession': None,
#   'is_public_domain': False,
#   'is_zoomable': False,
#   'max_zoom_window_size': 843,
#   'copyright_notice': None,
#   'has_multimedia_resources': False,
#   'has_educational_resources': False,
#   'has_advanced_imaging': False,
#   'colorfulness': None,
#   'color': None,
#   'latitude': None,
#   'longitude': None,
#   'latlon': None,
#   'is_on_view': False,
#   'on_loan_display': None,
#   'gallery_title': None,
#   'gallery_id': None,
#   'artwork_type_title': 'Photograph',
#   'artwork_type_id': 2,
#   'department_title': 'Photography and Media',
#   'department_id': 'PC-12',
#   'artist_id': 36744,
#   'artist_title': 'Eve Sonneman',
#   'alt_artist_ids': [],
#   'artist_ids': [36744],
#   'artist_titles': ['Eve Sonneman'],
#   'category_ids': ['PC-12'],
#   'category_titles': ['Photography and Media'],
#   'term_titles': ['photography', 'photograph', 'photographic process'],
#   'style_id': None,
#   'style_title': None,
#   'alt_style_ids': [],
#   'style_ids': [],
#   'style_titles': [],
#   'classification_id': 'TM-67',
#   'classification_title': 'photography',
#   'alt_classification_ids': ['TM-240', 'TM-68'],
#   'classification_ids': ['TM-67', 'TM-240', 'TM-68'],
#   'classification_titles': ['photography',
#    'photograph',
#    'photographic process'],
#   'subject_id': None,
#   'alt_subject_ids': [],
#   'subject_ids': [],
#   'subject_titles': [],
#   'material_id': None,
#   'alt_material_ids': [],
#   'material_ids': [],
#   'material_titles': [],
#   'technique_id': None,
#   'alt_technique_ids': [],
#   'technique_ids': [],
#   'technique_titles': [],
#   'theme_titles': [],
#   'image_id': None,
#   'alt_image_ids': [],
#   'document_ids': [],
#   'sound_ids': [],
#   'video_ids': [],
#   'text_ids': [],
#   'section_ids': [],
#   'section_titles': [],
#   'site_ids': [],
#   'suggest_autocomplete_all': [{'input': ['2022.1722'],
#     'contexts': {'groupings': ['accession']}},
#    {'input': ['Teeth Cases, Mexico'],
#     'weight': 1,
#     'contexts': {'groupings': ['title']}}],
#   'source_updated_at': '2023-02-09T15:02:44-06:00',
#   'updated_at': '2023-02-09T15:07:14-06:00',
#   'timestamp': '2023-02-09T15:24:09-06:00'},
#  {'id': 266235,
#   'api_model': 'artworks',
#   'api_link': 'https://api.artic.edu/api/v1/artworks/266235',
#   'is_boosted': False,
#   'title': 'Laura, New Mexico',
#   'alt_titles': None,
#   'thumbnail': None,
#   'main_reference_number': '2022.1721',
#   'has_not_been_viewed_much': True,
#   'boost_rank': None,
#   'date_start': 1968,
#   'date_end': 1968,
#   'date_display': '1968',
#   'date_qualifier_title': 'Made',
#   'date_qualifier_id': 4,
#   'artist_display': 'Eve Sonneman\nAmerican, born 1950',
#   'place_of_origin': 'United States',
#   'dimensions': 'Image: 10.8 × 32.5 cm (4 5/16 × 12 13/16 in.); paper: 11.2 × 33.5 cm (4 7/16 × 13 1/4 in.); mount: 28 × 45.7 cm (11 1/16 × 18 in.)',
#   'medium_display': 'Gelatin silver print',
#   'inscriptions': None,
#   'credit_line': 'Gift of the Daniel Weinberg Family',
#   'catalogue_display': None,
#   'publication_history': None,
#   'exhibition_history': None,
#   'provenance_text': None,
#   'publishing_verification_level': 'Web Basic',
#   'internal_department_id': 20,
#   'fiscal_year': 2023,
#   'fiscal_year_deaccession': None,
#   'is_public_domain': False,
#   'is_zoomable': False,
#   'max_zoom_window_size': 843,
#   'copyright_notice': None,
#   'has_multimedia_resources': False,
#   'has_educational_resources': False,
#   'has_advanced_imaging': False,
#   'colorfulness': None,
#   'color': None,
#   'latitude': None,
#   'longitude': None,
#   'latlon': None,
#   'is_on_view': False,
#   'on_loan_display': None,
#   'gallery_title': None,
#   'gallery_id': None,
#   'artwork_type_title': 'Photograph',
#   'artwork_type_id': 2,
#   'department_title': 'Photography and Media',
#   'department_id': 'PC-12',
#   'artist_id': 36744,
#   'artist_title': 'Eve Sonneman',
#   'alt_artist_ids': [],
#   'artist_ids': [36744],
#   'artist_titles': ['Eve Sonneman'],
#   'category_ids': ['PC-12'],
#   'category_titles': ['Photography and Media'],
#   'term_titles': ['photography', 'photograph', 'photographic process'],
#   'style_id': None,
#   'style_title': None,
#   'alt_style_ids': [],
#   'style_ids': [],
#   'style_titles': [],
#   'classification_id': 'TM-67',
#   'classification_title': 'photography',
#   'alt_classification_ids': ['TM-240', 'TM-68'],
#   'classification_ids': ['TM-67', 'TM-240', 'TM-68'],
#   'classification_titles': ['photography',
#    'photograph',
#    'photographic process'],
#   'subject_id': None,
#   'alt_subject_ids': [],
#   'subject_ids': [],
#   'subject_titles': [],
#   'material_id': None,
#   'alt_material_ids': [],
#   'material_ids': [],
#   'material_titles': [],
#   'technique_id': None,
#   'alt_technique_ids': [],
#   'technique_ids': [],
#   'technique_titles': [],
#   'theme_titles': [],
#   'image_id': None,
#   'alt_image_ids': [],
#   'document_ids': [],
#   'sound_ids': [],
#   'video_ids': [],
#   'text_ids': [],
#   'section_ids': [],
#   'section_titles': [],
#   'site_ids': [],
#   'suggest_autocomplete_all': [{'input': ['2022.1721'],
#     'contexts': {'groupings': ['accession']}},
#    {'input': ['Laura, New Mexico'],
#     'weight': 1,
#     'contexts': {'groupings': ['title']}}],
#   'source_updated_at': '2023-02-09T15:02:44-06:00',
#   'updated_at': '2023-02-09T15:07:14-06:00',
#   'timestamp': '2023-02-09T15:24:09-06:00'},
#  {'id': 265937,
#   'api_model': 'artworks',
#   'api_link': 'https://api.artic.edu/api/v1/artworks/265937',
#   'is_boosted': False,
#   'title': 'Portrait of Dorothea Lange by Window',
#   'alt_titles': None,
#   'thumbnail': None,
#   'main_reference_number': '2022.1718',
#   'has_not_been_viewed_much': True,
#   'boost_rank': None,
#   'date_start': None,
#   'date_end': None,
#   'date_display': '1960s',
#   'date_qualifier_title': '',
#   'date_qualifier_id': None,
#   'artist_display': 'Ronald Partridge\nAmerican, 1917-2015',
#   'place_of_origin': 'United States',
#   'dimensions': '45.1 × 37.5 cm (17 3/4 × 14 3/4 in.); Image: 22.8 × 14.9 cm (9 × 5 7/8 in.); mount: 43 × 35.6 cm (16 15/16 × 14 1/16 in.)',
#   'medium_display': 'Gelatin silver print',
#   'inscriptions': None,
#   'credit_line': 'Gift of Lucia Woods Lindley',
#   'catalogue_display': None,
#   'publication_history': None,
#   'exhibition_history': None,
#   'provenance_text': None,
#   'publishing_verification_level': 'Web Basic',
#   'internal_department_id': 20,
#   'fiscal_year': 2023,
#   'fiscal_year_deaccession': None,
#   'is_public_domain': False,
#   'is_zoomable': False,
#   'max_zoom_window_size': 843,
#   'copyright_notice': None,
#   'has_multimedia_resources': False,
#   'has_educational_resources': False,
#   'has_advanced_imaging': False,
#   'colorfulness': None,
#   'color': None,
#   'latitude': None,
#   'longitude': None,
#   'latlon': None,
#   'is_on_view': False,
#   'on_loan_display': None,
#   'gallery_title': None,
#   'gallery_id': None,
#   'artwork_type_title': 'Photograph',
#   'artwork_type_id': 2,
#   'department_title': 'Photography and Media',
#   'department_id': 'PC-12',
#   'artist_id': 97471,
#   'artist_title': 'Rondal Partridge',
#   'alt_artist_ids': [],
#   'artist_ids': [97471],
#   'artist_titles': ['Rondal Partridge'],
#   'category_ids': ['PC-12'],
#   'category_titles': ['Photography and Media'],
#   'term_titles': ['photography', 'photograph', 'photographic process'],
#   'style_id': None,
#   'style_title': None,
#   'alt_style_ids': [],
#   'style_ids': [],
#   'style_titles': [],
#   'classification_id': 'TM-67',
#   'classification_title': 'photography',
#   'alt_classification_ids': ['TM-240', 'TM-68'],
#   'classification_ids': ['TM-67', 'TM-240', 'TM-68'],
#   'classification_titles': ['photography',
#    'photograph',
#    'photographic process'],
#   'subject_id': None,
#   'alt_subject_ids': [],
#   'subject_ids': [],
#   'subject_titles': [],
#   'material_id': None,
#   'alt_material_ids': [],
#   'material_ids': [],
#   'material_titles': [],
#   'technique_id': None,
#   'alt_technique_ids': [],
#   'technique_ids': [],
#   'technique_titles': [],
#   'theme_titles': [],
#   'image_id': None,
#   'alt_image_ids': [],
#   'document_ids': [],
#   'sound_ids': [],
#   'video_ids': [],
#   'text_ids': [],
#   'section_ids': [],
#   'section_titles': [],
#   'site_ids': [],
#   'suggest_autocomplete_all': [{'input': ['2022.1718'],
#     'contexts': {'groupings': ['accession']}},
#    {'input': ['Portrait of Dorothea Lange by Window'],
#     'weight': 1,
#     'contexts': {'groupings': ['title']}}],
#   'source_updated_at': '2023-02-09T15:03:28-06:00',
#   'updated_at': '2023-02-09T15:07:14-06:00',
#   'timestamp': '2023-02-09T15:24:09-06:00'},
#  {'id': 262570,
#   'api_model': 'artworks',
#   'api_link': 'https://api.artic.edu/api/v1/artworks/262570',
#   'is_boosted': False,
#   'title': 'Somalia (#7 of 7)',
#   'alt_titles': None,
#   'thumbnail': {'lqip': '...',
#    'width': 8945,
#    'height': 7152,
#    'alt_text': 'A work made of gelatin silver print with hand applied lettering.'},
#   'main_reference_number': '2021.520.7',
#   'has_not_been_viewed_much': True,
#   'boost_rank': None,
#   'date_start': None,
#   'date_end': None,
#   'date_display': '1993',
#   'date_qualifier_title': '',
#   'date_qualifier_id': None,
#   'artist_display': 'Lewis Koch\nAmerican, born 1949',
#   'place_of_origin': 'United States',
#   'dimensions': 'Image: 47.4 × 37.2 cm (18 11/16 × 14 11/16 in.)',
#   'medium_display': 'Gelatin silver print with hand applied lettering',
#   'inscriptions': None,
#   'credit_line': 'Gift of the artist',
#   'catalogue_display': None,
#   'publication_history': None,
#   'exhibition_history': None,
#   'provenance_text': None,
#   'publishing_verification_level': 'Web Basic',
#   'internal_department_id': 20,
#   'fiscal_year': 2022,
#   'fiscal_year_deaccession': None,
#   'is_public_domain': False,
#   'is_zoomable': False,
#   'max_zoom_window_size': 843,
#   'copyright_notice': None,
#   'has_multimedia_resources': False,
#   'has_educational_resources': False,
#   'has_advanced_imaging': False,
#   'colorfulness': 0,
#   'color': {'h': 349,
#    'l': 42,
#    's': 62,
#    'percentage': 6.2524775442269e-06,
#    'population': 4},
#   'latitude': None,
#   'longitude': None,
#   'latlon': None,
#   'is_on_view': False,
#   'on_loan_display': None,
#   'gallery_title': None,
#   'gallery_id': None,
#   'artwork_type_title': 'Photograph',
#   'artwork_type_id': 2,
#   'department_title': 'Photography and Media',
#   'department_id': 'PC-12',
#   'artist_id': 117763,
#   'artist_title': 'Lewis Koch',
#   'alt_artist_ids': [],
#   'artist_ids': [117763],
#   'artist_titles': ['Lewis Koch'],
#   'category_ids': ['PC-12'],
#   'category_titles': ['Photography and Media'],
#   'term_titles': ['photography', 'photograph', 'photographic process'],
#   'style_id': None,
#   'style_title': None,
#   'alt_style_ids': [],
#   'style_ids': [],
#   'style_titles': [],
#   'classification_id': 'TM-67',
#   'classification_title': 'photography',
#   'alt_classification_ids': ['TM-240', 'TM-68'],
#   'classification_ids': ['TM-67', 'TM-240', 'TM-68'],
#   'classification_titles': ['photography',
#    'photograph',
#    'photographic process'],
#   'subject_id': None,
#   'alt_subject_ids': [],
#   'subject_ids': [],
#   'subject_titles': [],
#   'material_id': None,
#   'alt_material_ids': [],
#   'material_ids': [],
#   'material_titles': [],
#   'technique_id': None,
#   'alt_technique_ids': [],
#   'technique_ids': [],
#   'technique_titles': [],
#   'theme_titles': [],
#   'image_id': 'ee81c391-415d-6ea2-cda0-bb270bde143f',
#   'alt_image_ids': ['778d419f-ed53-d105-aa9c-28393c135c48',
#    'ca2970f4-573f-cf1e-602e-2eeb7cb2a0e0'],
#   'document_ids': [],
#   'sound_ids': [],
#   'video_ids': [],
#   'text_ids': [],
#   'section_ids': [],
#   'section_titles': [],
#   'site_ids': [],
#   'suggest_autocomplete_all': [{'input': ['2021.520.7'],
#     'contexts': {'groupings': ['accession']}},
#    {'input': ['Somalia (#7 of 7)'],
#     'weight': 1,
#     'contexts': {'groupings': ['title']}}],
#   'source_updated_at': '2023-02-09T15:04:51-06:00',
#   'updated_at': '2023-02-09T15:07:13-06:00',
#   'timestamp': '2023-02-09T15:24:09-06:00'},
#  {'id': 262569,
#   'api_model': 'artworks',
#   'api_link': 'https://api.artic.edu/api/v1/artworks/262569',
#   'is_boosted': False,
#   'title': 'Washington, D.C. (#6 of 7)',
#   'alt_titles': None,
#   'thumbnail': {'lqip': '...',
#    'width': 8931,
#    'height': 7164,
#    'alt_text': 'A work made of gelatin silver print with hand applied lettering.'},
#   'main_reference_number': '2021.520.6',
#   'has_not_been_viewed_much': True,
#   'boost_rank': None,
#   'date_start': None,
#   'date_end': None,
#   'date_display': '1993',
#   'date_qualifier_title': '',
#   'date_qualifier_id': None,
#   'artist_display': 'Lewis Koch\nAmerican, born 1949',
#   'place_of_origin': 'United States',
#   'dimensions': 'Image: 47.4 × 37.2 cm (18 11/16 × 14 11/16 in.)',
#   'medium_display': 'Gelatin silver print with hand applied lettering',
#   'inscriptions': None,
#   'credit_line': 'Gift of the artist',
#   'catalogue_display': None,
#   'publication_history': None,
#   'exhibition_history': None,
#   'provenance_text': None,
#   'publishing_verification_level': 'Web Basic',
#   'internal_department_id': 20,
#   'fiscal_year': 2022,
#   'fiscal_year_deaccession': None,
#   'is_public_domain': False,
#   'is_zoomable': False,
#   'max_zoom_window_size': 843,
#   'copyright_notice': None,
#   'has_multimedia_resources': False,
#   'has_educational_resources': False,
#   'has_advanced_imaging': False,
#   'colorfulness': 0,
#   'color': {'h': 6,
#    'l': 35,
#    's': 70,
#    'percentage': 2.9695998623606092e-05,
#    'population': 19},
#   'latitude': None,
#   'longitude': None,
#   'latlon': None,
#   'is_on_view': False,
#   'on_loan_display': None,
#   'gallery_title': None,
#   'gallery_id': None,
#   'artwork_type_title': 'Photograph',
#   'artwork_type_id': 2,
#   'department_title': 'Photography and Media',
#   'department_id': 'PC-12',
#   'artist_id': 117763,
#   'artist_title': 'Lewis Koch',
#   'alt_artist_ids': [],
#   'artist_ids': [117763],
#   'artist_titles': ['Lewis Koch'],
#   'category_ids': ['PC-12'],
#   'category_titles': ['Photography and Media'],
#   'term_titles': ['photography', 'photograph', 'photographic process'],
#   'style_id': None,
#   'style_title': None,
#   'alt_style_ids': [],
#   'style_ids': [],
#   'style_titles': [],
#   'classification_id': 'TM-67',
#   'classification_title': 'photography',
#   'alt_classification_ids': ['TM-240', 'TM-68'],
#   'classification_ids': ['TM-67', 'TM-240', 'TM-68'],
#   'classification_titles': ['photography',
#    'photograph',
#    'photographic process'],
#   'subject_id': None,
#   'alt_subject_ids': [],
#   'subject_ids': [],
#   'subject_titles': [],
#   'material_id': None,
#   'alt_material_ids': [],
#   'material_ids': [],
#   'material_titles': [],
#   'technique_id': None,
#   'alt_technique_ids': [],
#   'technique_ids': [],
#   'technique_titles': [],
#   'theme_titles': [],
#   'image_id': 'f54a70c4-d6aa-9e32-9542-37c58696726c',
#   'alt_image_ids': ['dcd1c790-bfe0-a2b7-9d5e-b93c6ee13d71',
#    '8aadbd03-7b2b-9db8-1e3f-38916edf2765'],
#   'document_ids': [],
#   'sound_ids': [],
#   'video_ids': [],
#   'text_ids': [],
#   'section_ids': [],
#   'section_titles': [],
#   'site_ids': [],
#   'suggest_autocomplete_all': [{'input': ['2021.520.6'],
#     'contexts': {'groupings': ['accession']}},
#    {'input': ['Washington, D.C. (#6 of 7)'],
#     'weight': 1,
#     'contexts': {'groupings': ['title']}}],
#   'source_updated_at': '2023-02-09T15:04:51-06:00',
#   'updated_at': '2023-02-09T15:07:13-06:00',
#   'timestamp': '2023-02-09T15:24:09-06:00'},
#  {'id': 262564,
#   'api_model': 'artworks',
#   'api_link': 'https://api.artic.edu/api/v1/artworks/262564',
#   'is_boosted': False,
#   'title': 'Bosnia (#1 of 7)',
#   'alt_titles': None,
#   'thumbnail': {'lqip': '...',
#    'width': 8992,
#    'height': 7166,
#    'alt_text': 'A work made of gelatin silver print with hand applied lettering.'},
#   'main_reference_number': '2021.520.1',
#   'has_not_been_viewed_much': True,
#   'boost_rank': None,
#   'date_start': 1993,
#   'date_end': 1993,
#   'date_display': '1993',
#   'date_qualifier_title': 'Made',
#   'date_qualifier_id': 4,
#   'artist_display': 'Lewis Koch\nAmerican, born 1949',
#   'place_of_origin': 'United States',
#   'dimensions': 'Image: 47.4 × 19.1 cm (18 11/16 × 7 9/16 in.)',
#   'medium_display': 'Gelatin silver print with hand applied lettering',
#   'inscriptions': None,
#   'credit_line': 'Gift of the artist',
#   'catalogue_display': None,
#   'publication_history': None,
#   'exhibition_history': None,
#   'provenance_text': None,
#   'publishing_verification_level': 'Web Basic',
#   'internal_department_id': 20,
#   'fiscal_year': 2022,
#   'fiscal_year_deaccession': None,
#   'is_public_domain': False,
#   'is_zoomable': False,
#   'max_zoom_window_size': 843,
#   'copyright_notice': None,
#   'has_multimedia_resources': False,
#   'has_educational_resources': False,
#   'has_advanced_imaging': False,
#   'colorfulness': 0,
#   'color': {'h': 359,
#    'l': 36,
#    's': 64,
#    'percentage': 1.551911309137753e-05,
#    'population': 10},
#   'latitude': None,
#   'longitude': None,
#   'latlon': None,
#   'is_on_view': False,
#   'on_loan_display': None,
#   'gallery_title': None,
#   'gallery_id': None,
#   'artwork_type_title': 'Photograph',
#   'artwork_type_id': 2,
#   'department_title': 'Photography and Media',
#   'department_id': 'PC-12',
#   'artist_id': 117763,
#   'artist_title': 'Lewis Koch',
#   'alt_artist_ids': [],
#   'artist_ids': [117763],
#   'artist_titles': ['Lewis Koch'],
#   'category_ids': ['PC-12'],
#   'category_titles': ['Photography and Media'],
#   'term_titles': ['photography', 'photograph', 'photographic process'],
#   'style_id': None,
#   'style_title': None,
#   'alt_style_ids': [],
#   'style_ids': [],
#   'style_titles': [],
#   'classification_id': 'TM-67',
#   'classification_title': 'photography',
#   'alt_classification_ids': ['TM-240', 'TM-68'],
#   'classification_ids': ['TM-67', 'TM-240', 'TM-68'],
#   'classification_titles': ['photography',
#    'photograph',
#    'photographic process'],
#   'subject_id': None,
#   'alt_subject_ids': [],
#   'subject_ids': [],
#   'subject_titles': [],
#   'material_id': None,
#   'alt_material_ids': [],
#   'material_ids': [],
#   'material_titles': [],
#   'technique_id': None,
#   'alt_technique_ids': [],
#   'technique_ids': [],
#   'technique_titles': [],
#   'theme_titles': [],
#   'image_id': 'cb000d56-1313-d68c-53d3-a7d9554bb4db',
#   'alt_image_ids': ['a203f43a-f06b-8705-ba7a-290011722d3a',
#    'a6360105-ac9e-761d-6073-fc3108a33b48'],
#   'document_ids': [],
#   'sound_ids': [],
#   'video_ids': [],
#   'text_ids': [],
#   'section_ids': [],
#   'section_titles': [],
#   'site_ids': [],
#   'suggest_autocomplete_all': [{'input': ['2021.520.1'],
#     'contexts': {'groupings': ['accession']}},
#    {'input': ['Bosnia (#1 of 7)'],
#     'weight': 1,
#     'contexts': {'groupings': ['title']}}],
#   'source_updated_at': '2023-02-09T15:04:51-06:00',
#   'updated_at': '2023-02-09T15:07:13-06:00',
#   'timestamp': '2023-02-09T15:24:09-06:00'},
#  {'id': 262567,
#   'api_model': 'artworks',
#   'api_link': 'https://api.artic.edu/api/v1/artworks/262567',
#   'is_boosted': False,
#   'title': 'East Timor (#4 of 7)',
#   'alt_titles': None,
#   'thumbnail': {'lqip': '...',
#    'width': 8943,
#    'height': 7178,
#    'alt_text': 'A work made of gelatin silver print with hand applied lettering.'},
#   'main_reference_number': '2021.520.3',
#   'has_not_been_viewed_much': True,
#   'boost_rank': None,
#   'date_start': 1993,
#   'date_end': 1993,
#   'date_display': '1993',
#   'date_qualifier_title': 'Made',
#   'date_qualifier_id': 4,
#   'artist_display': 'Lewis Koch\nAmerican, born 1949',
#   'place_of_origin': 'United States',
#   'dimensions': 'Image: 47.4 × 37.1 cm (18 11/16 × 14 5/8 in.)',
#   'medium_display': 'Gelatin silver print with hand applied lettering',
#   'inscriptions': None,
#   'credit_line': 'Gift of the artist',
#   'catalogue_display': None,
#   'publication_history': None,
#   'exhibition_history': None,
#   'provenance_text': None,
#   'publishing_verification_level': 'Web Basic',
#   'internal_department_id': 20,
#   'fiscal_year': 2022,
#   'fiscal_year_deaccession': None,
#   'is_public_domain': False,
#   'is_zoomable': False,
#   'max_zoom_window_size': 843,
#   'copyright_notice': None,
#   'has_multimedia_resources': False,
#   'has_educational_resources': False,
#   'has_advanced_imaging': False,
#   'colorfulness': 0,
#   'color': {'h': 356,
#    'l': 51,
#    's': 29,
#    'percentage': 6.2312231825679536e-06,
#    'population': 4},
#   'latitude': None,
#   'longitude': None,
#   'latlon': None,
#   'is_on_view': False,
#   'on_loan_display': None,
#   'gallery_title': None,
#   'gallery_id': None,
#   'artwork_type_title': 'Photograph',
#   'artwork_type_id': 2,
#   'department_title': 'Photography and Media',
#   'department_id': 'PC-12',
#   'artist_id': 117763,
#   'artist_title': 'Lewis Koch',
#   'alt_artist_ids': [],
#   'artist_ids': [117763],
#   'artist_titles': ['Lewis Koch'],
#   'category_ids': ['PC-12'],
#   'category_titles': ['Photography and Media'],
#   'term_titles': ['photography', 'photograph', 'photographic process'],
#   'style_id': None,
#   'style_title': None,
#   'alt_style_ids': [],
#   'style_ids': [],
#   'style_titles': [],
#   'classification_id': 'TM-67',
#   'classification_title': 'photography',
#   'alt_classification_ids': ['TM-240', 'TM-68'],
#   'classification_ids': ['TM-67', 'TM-240', 'TM-68'],
#   'classification_titles': ['photography',
#    'photograph',
#    'photographic process'],
#   'subject_id': None,
#   'alt_subject_ids': [],
#   'subject_ids': [],
#   'subject_titles': [],
#   'material_id': None,
#   'alt_material_ids': [],
#   'material_ids': [],
#   'material_titles': [],
#   'technique_id': None,
#   'alt_technique_ids': [],
#   'technique_ids': [],
#   'technique_titles': [],
#   'theme_titles': [],
#   'image_id': 'b4c53ae7-3033-131c-ec92-f8c07f267fe9',
#   'alt_image_ids': ['eb6ef5b3-00dc-6789-54ff-38af0bff4ab0',
#    '6c16a419-923f-78bf-7f70-7540361b89dc'],
#   'document_ids': [],
#   'sound_ids': [],
#   'video_ids': [],
#   'text_ids': [],
#   'section_ids': [],
#   'section_titles': [],
#   'site_ids': [],
#   'suggest_autocomplete_all': [{'input': ['2021.520.3'],
#     'contexts': {'groupings': ['accession']}},
#    {'input': ['East Timor (#4 of 7)'],
#     'weight': 1,
#     'contexts': {'groupings': ['title']}}],
#   'source_updated_at': '2023-02-09T15:06:37-06:00',
#   'updated_at': '2023-02-09T15:07:12-06:00',
#   'timestamp': '2023-02-09T15:24:09-06:00'},
#  {'id': 262566,
#   'api_model': 'artworks',
#   'api_link': 'https://api.artic.edu/api/v1/artworks/262566',
#   'is_boosted': False,
#   'title': 'Columbia (#3 of 7)',
#   'alt_titles': None,
#   'thumbnail': {'lqip': '...',
#    'width': 8977,
#    'height': 7171,
#    'alt_text': 'A work made of gelatin silver print with hand applied lettering.'},
#   'main_reference_number': '2021.520.5',
#   'has_not_been_viewed_much': True,
#   'boost_rank': None,
#   'date_start': 1993,
#   'date_end': 1993,
#   'date_display': '1993',
#   'date_qualifier_title': 'Made',
#   'date_qualifier_id': 4,
#   'artist_display': 'Lewis Koch\nAmerican, born 1949',
#   'place_of_origin': 'United States',
#   'dimensions': 'Image: 47.5 × 37.1 cm (18 3/4 × 14 5/8 in.)',
#   'medium_display': 'Gelatin silver print with hand applied lettering',
#   'inscriptions': None,
#   'credit_line': 'Gift of the artist',
#   'catalogue_display': None,
#   'publication_history': None,
#   'exhibition_history': None,
#   'provenance_text': None,
#   'publishing_verification_level': 'Web Basic',
#   'internal_department_id': 20,
#   'fiscal_year': 2022,
#   'fiscal_year_deaccession': None,
#   'is_public_domain': False,
#   'is_zoomable': False,
#   'max_zoom_window_size': 843,
#   'copyright_notice': None,
#   'has_multimedia_resources': False,
#   'has_educational_resources': False,
#   'has_advanced_imaging': False,
#   'colorfulness': 0,
#   'color': {'h': 357,
#    'l': 50,
#    's': 62,
#    'percentage': 1.553420572293498e-06,
#    'population': 1},
#   'latitude': None,
#   'longitude': None,
#   'latlon': None,
#   'is_on_view': False,
#   'on_loan_display': None,
#   'gallery_title': None,
#   'gallery_id': None,
#   'artwork_type_title': 'Photograph',
#   'artwork_type_id': 2,
#   'department_title': 'Photography and Media',
#   'department_id': 'PC-12',
#   'artist_id': 117763,
#   'artist_title': 'Lewis Koch',
#   'alt_artist_ids': [],
#   'artist_ids': [117763],
#   'artist_titles': ['Lewis Koch'],
#   'category_ids': ['PC-12'],
#   'category_titles': ['Photography and Media'],
#   'term_titles': ['photography', 'photograph', 'photographic process'],
#   'style_id': None,
#   'style_title': None,
#   'alt_style_ids': [],
#   'style_ids': [],
#   'style_titles': [],
#   'classification_id': 'TM-67',
#   'classification_title': 'photography',
#   'alt_classification_ids': ['TM-240', 'TM-68'],
#   'classification_ids': ['TM-67', 'TM-240', 'TM-68'],
#   'classification_titles': ['photography',
#    'photograph',
#    'photographic process'],
#   'subject_id': None,
#   'alt_subject_ids': [],
#   'subject_ids': [],
#   'subject_titles': [],
#   'material_id': None,
#   'alt_material_ids': [],
#   'material_ids': [],
#   'material_titles': [],
#   'technique_id': None,
#   'alt_technique_ids': [],
#   'technique_ids': [],
#   'technique_titles': [],
#   'theme_titles': [],
#   'image_id': '8fb75438-df95-287b-13eb-fc16794db455',
#   'alt_image_ids': ['580f2b0d-0497-739c-dd2a-47e554522085',
#    'd18e2c60-7b24-71d2-d738-69dab5cf8078'],
#   'document_ids': [],
#   'sound_ids': [],
#   'video_ids': [],
#   'text_ids': [],
#   'section_ids': [],
#   'section_titles': [],
#   'site_ids': [],
#   'suggest_autocomplete_all': [{'input': ['2021.520.5'],
#     'contexts': {'groupings': ['accession']}},
#    {'input': ['Columbia (#3 of 7)'],
#     'weight': 1,
#     'contexts': {'groupings': ['title']}}],
#   'source_updated_at': '2023-02-09T15:06:15-06:00',
#   'updated_at': '2023-02-09T15:07:12-06:00',
#   'timestamp': '2023-02-09T15:24:09-06:00'},
#  {'id': 262565,
#   'api_model': 'artworks',
#   'api_link': 'https://api.artic.edu/api/v1/artworks/262565',
#   'is_boosted': False,
#   'title': 'Azerbaijan (#2 of 7)',
#   'alt_titles': None,
#   'thumbnail': {'lqip': '...',
#    'width': 8986,
#    'height': 7147,
#    'alt_text': 'A work made of gelatin silver print with hand applied lettering.'},
#   'main_reference_number': '2021.520.4',
#   'has_not_been_viewed_much': True,
#   'boost_rank': None,
#   'date_start': None,
#   'date_end': None,
#   'date_display': '1993',
#   'date_qualifier_title': '',
#   'date_qualifier_id': None,
#   'artist_display': 'Lewis Koch\nAmerican, born 1949',
#   'place_of_origin': 'United States',
#   'dimensions': 'Image: 47.4 × 37.1 cm (18 11/16 × 14 5/8 in.)',
#   'medium_display': 'Gelatin silver print with hand applied lettering',
#   'inscriptions': None,
#   'credit_line': 'Gift of the artist',
#   'catalogue_display': None,
#   'publication_history': None,
#   'exhibition_history': None,
#   'provenance_text': None,
#   'publishing_verification_level': 'Web Basic',
#   'internal_department_id': 20,
#   'fiscal_year': 2022,
#   'fiscal_year_deaccession': None,
#   'is_public_domain': False,
#   'is_zoomable': False,
#   'max_zoom_window_size': 843,
#   'copyright_notice': None,
#   'has_multimedia_resources': False,
#   'has_educational_resources': False,
#   'has_advanced_imaging': False,
#   'colorfulness': 0,
#   'color': {'h': 358,
#    'l': 34,
#    's': 63,
#    'percentage': 3.4255671439031866e-05,
#    'population': 22},
#   'latitude': None,
#   'longitude': None,
#   'latlon': None,
#   'is_on_view': False,
#   'on_loan_display': None,
#   'gallery_title': None,
#   'gallery_id': None,
#   'artwork_type_title': 'Photograph',
#   'artwork_type_id': 2,
#   'department_title': 'Photography and Media',
#   'department_id': 'PC-12',
#   'artist_id': 117763,
#   'artist_title': 'Lewis Koch',
#   'alt_artist_ids': [],
#   'artist_ids': [117763],
#   'artist_titles': ['Lewis Koch'],
#   'category_ids': ['PC-12'],
#   'category_titles': ['Photography and Media'],
#   'term_titles': ['photography', 'photograph', 'photographic process'],
#   'style_id': None,
#   'style_title': None,
#   'alt_style_ids': [],
#   'style_ids': [],
#   'style_titles': [],
#   'classification_id': 'TM-67',
#   'classification_title': 'photography',
#   'alt_classification_ids': ['TM-240', 'TM-68'],
#   'classification_ids': ['TM-67', 'TM-240', 'TM-68'],
#   'classification_titles': ['photography',
#    'photograph',
#    'photographic process'],
#   'subject_id': None,
#   'alt_subject_ids': [],
#   'subject_ids': [],
#   'subject_titles': [],
#   'material_id': None,
#   'alt_material_ids': [],
#   'material_ids': [],
#   'material_titles': [],
#   'technique_id': None,
#   'alt_technique_ids': [],
#   'technique_ids': [],
#   'technique_titles': [],
#   'theme_titles': [],
#   'image_id': 'ff8297a1-facb-87ba-af0a-f5728970cc2d',
#   'alt_image_ids': ['86047627-c029-f9b2-a47b-64536adef6d5',
#    '978a9759-aa4d-ffe4-bcbf-e09874d63152'],
#   'document_ids': [],
#   'sound_ids': [],
#   'video_ids': [],
#   'text_ids': [],
#   'section_ids': [],
#   'section_titles': [],
#   'site_ids': [],
#   'suggest_autocomplete_all': [{'input': ['2021.520.4'],
#     'contexts': {'groupings': ['accession']}},
#    {'input': ['Azerbaijan (#2 of 7)'],
#     'weight': 1,
#     'contexts': {'groupings': ['title']}}],
#   'source_updated_at': '2023-02-09T15:05:24-06:00',
#   'updated_at': '2023-02-09T15:07:12-06:00',
#   'timestamp': '2023-02-09T15:24:09-06:00'}]

# %%
df_api = pd.json_normalize(r.json(),'data')
df_api_filter=df_api.filter(items=['title','date_start','date_end','place_of_origin','classification_title','artist_title','artwork_type_title','department_title','medium_display'])
#print(df_api.shape)

# %%
df_api_filter.shape
# Out:
# (12, 9)

# %%
df_api.artist_title.unique()
# Out:
# array([None, 'Gauri Gill', 'Islamic', 'Eve Sonneman', 'Rondal Partridge',
#        'Lewis Koch'], dtype=object)

# %%
df_api_filter[df_api_filter['place_of_origin'] == 'United States']
# Out:
#                                    title  date_start  date_end  \
# 3                    Teeth Cases, Mexico      1975.0    1975.0
# 4                      Laura, New Mexico      1968.0    1968.0
# 5   Portrait of Dorothea Lange by Window         NaN       NaN
# 6                      Somalia (#7 of 7)         NaN       NaN
# 7             Washington, D.C. (#6 of 7)         NaN       NaN
# 8                       Bosnia (#1 of 7)      1993.0    1993.0
# 9                   East Timor (#4 of 7)      1993.0    1993.0
# 10                    Columbia (#3 of 7)      1993.0    1993.0
# 11                  Azerbaijan (#2 of 7)         NaN       NaN
#
#    place_of_origin classification_title      artist_title artwork_type_title  \
# 3    United States          photography      Eve Sonneman         Photograph
# 4    United States          photography      Eve Sonneman         Photograph
# 5    United States          photography  Rondal Partridge         Photograph
# 6    United States          photography        Lewis Koch         Photograph
# 7    United States          photography        Lewis Koch         Photograph
# 8    United States          photography        Lewis Koch         Photograph
# 9    United States          photography        Lewis Koch         Photograph
# 10   United States          photography        Lewis Koch         Photograph
# 11   United States          photography        Lewis Koch         Photograph
#
#          department_title                                    medium_display
# 3   Photography and Media                              Gelatin silver print
# 4   Photography and Media                              Gelatin silver print
# 5   Photography and Media                              Gelatin silver print
# 6   Photography and Media  Gelatin silver print with hand applied lettering
# 7   Photography and Media  Gelatin silver print with hand applied lettering
# 8   Photography and Media  Gelatin silver print with hand applied lettering
# 9   Photography and Media  Gelatin silver print with hand applied lettering
# 10  Photography and Media  Gelatin silver print with hand applied lettering
# 11  Photography and Media  Gelatin silver print with hand applied lettering

# %%
df_api_filter[['date_start','date_end']].head()
# Out:
#    date_start  date_end
# 0       800.0     900.0
# 1      1999.0    2007.0
# 2      1650.0    1750.0
# 3      1975.0    1975.0
# 4      1968.0    1968.0

# %%
df_api_filter.iloc[0:4]
# Out:
#                                  title  date_start  date_end place_of_origin  \
# 0                           God Brahma       800.0     900.0           Bihar
# 1                               Jannat      1999.0    2007.0           India
# 2  Ewer with Incised Floral Decoration      1650.0    1750.0            Iran
# 3                  Teeth Cases, Mexico      1975.0    1975.0   United States
#
#    classification_title  artist_title artwork_type_title  \
# 0                 stone          None          Sculpture
# 1  gelatin silver print    Gauri Gill         Photograph
# 2         ewer (vessel)       Islamic           Ceramics
# 3           photography  Eve Sonneman         Photograph
#
#         department_title                                     medium_display
# 0           Arts of Asia                                             Basalt
# 1  Photography and Media                                       Inkjet print
# 2           Arts of Asia  Gombroon ware; fritware with incised decoratio...
# 3  Photography and Media                               Gelatin silver print
